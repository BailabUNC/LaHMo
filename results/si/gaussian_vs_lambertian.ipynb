# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
theta = np.linspace(-np.pi / 2, np.pi / 2, 100)
A = 2
sigma = 0.75
I0 = 1
I1 = I0 * np.cos(theta)
I2 = A * norm(scale=sigma).pdf(theta)

plt.plot(theta, I1)
plt.plot(theta, I2)
plt.show()
