# %%
import numpy as np
import pandas as pd
import matplotlib as mpl

mpl.rcParams['font.family'] = 'arial'
mpl.rcParams['font.size'] = 14

import matplotlib.pyplot as plt

# %%
pv_path = '../../dataset/pv_raw/walking.npy'
or_path = '../../dataset/orientation_raw/walking_or_raw.txt'
interval_path = '../../dataset/orientation_raw/walking_expanded_peaks.txt'

pv = np.load(pv_path)[:, :4, :]

ori = pd.read_csv(or_path, header=None, delimiter='\t').to_numpy()
expanded_peaks = pd.read_csv(interval_path, header=None, delimiter='\t').to_numpy()

timestamp = ori[:, 0][expanded_peaks]
y = ori[:, 1][expanded_peaks]
p = ori[:, 2][expanded_peaks]
r = ori[:, 3][expanded_peaks]

# %%
pv.shape
# Out:
# (12, 4, 1000)

# %%
for slice in p:
    plt.plot(slice)

# %%
plt.plot(np.mean(r, axis=0))

# %%
pv[0].shape
# Out:
# (4, 1000)
